# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import random
import shutil
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
anno_path = "/content/drive/MyDrive/techno_pro/data/train_annotations.tsv"
anno_df = pd.read_csv(anno_path, delimiter='\t')

# %%
anno_df.head()
# Out:
#            id  label pattern  ...  rotation_angle  x_position  y_position
# 0  train_0000      1       B  ...           -0.49      393.00       85.00
# 1  train_0001      1       D  ...           -0.64      102.36      154.91
# 2  train_0002      0       A  ...             NaN         NaN         NaN
# 3  train_0003      1       B  ...           -0.35      232.00      306.00
# 4  train_0004      0       A  ...             NaN         NaN         NaN
#
# [5 rows x 8 columns]

# %%
out_pattern = 'D' #@param ['A', 'B', 'C', 'D']
for index, row in anno_df.iterrows():
  before_path = train_path + str(row["id"]) + ".png"
  if row["pattern"]==out_pattern:
    if row["label"]==1:
      after_path = train_path + "valid_"+out_pattern+"/1/"
      new_path = shutil.copy(before_path, after_path)
    elif row["label"]==0:
      after_path = train_path + "valid_"+out_pattern+"/0/"
      new_path = shutil.copy(before_path, after_path)
    else:
      print("error.")
      break
    print(new_path)
  else:
    if row["label"]==1:
      after_path = train_path + "train_"+out_pattern+"/1/"
      new_path = shutil.copy(before_path, after_path)
    elif row["label"]==0:
      after_path = train_path + "train_"+out_pattern+"/0/"
      new_path = shutil.copy(before_path, after_path)
    else:
      print("error.")
      break
# Out:
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/1/train_0001.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0007.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0010.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0011.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0012.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0016.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0018.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0022.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0023.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/1/train_0024.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0026.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0029.png
# /content/drive/MyDrive/techno_pro/data/train_out/valid_D/0/train_0045.png
# ...
