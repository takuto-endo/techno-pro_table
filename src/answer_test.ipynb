# %% [markdown]
# #1.モデルの準備

# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import random
import os

from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow._api.v2 import image

import time

# %% [markdown]
# #2.データセットの準備

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sab_path = "/content/drive/MyDrive/techno_pro/submit/sample_answer.tsv"
sab_df = pd.read_csv(sab_path, delimiter='\t', header=None)
sab_df.head()
# Out:
#            0    1
# 0  test_0000  1.0
# 1  test_0001  0.0
# 2  test_0002  0.0
# 3  test_0003  0.0
# 4  test_0004  0.0

# %%
# 確認
model_path = "1641367273_efficientnetv2-b0_32batch_8epoch"
temp_path = '/content/drive/MyDrive/techno_pro/submit/'+model_path+'.tsv'
temp_df = pd.read_csv(temp_path, delimiter='\t', header=None)
temp_df.head()

# %%
sab_df[1].describe()

# %%
sab_df.info()

# %%
sab_df[sab_df[1].isnull()]

# %%
sab_df.iloc[1589, 1] = 0

# %%
temp_df[1].describe()

# %%
temp_df.info()

# %%
from sklearn import metrics

# FPR, TPR(, しきい値) を算出
fpr, tpr, thresholds = metrics.roc_curve(sab_df[1], temp_df[1])

# ついでにAUCも
auc = metrics.auc(fpr, tpr)

# %%
auc

# %%
# ROC曲線をプロット
plt.plot(fpr, tpr, label='ROC curve (area = %.2f)'%auc)
plt.legend()
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
sab_df[(temp_df[1]>0.01) & (sab_df[1]==0)].head(50)

# %%
sab_df[(temp_df[1]<=0.01) & (sab_df[1]==1)].head(50)
