# %%
import numpy as np
import pandas as pd
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
test_path = "/content/drive/MyDrive/techno_pro/data/test/"
for f_name in glob.glob(test_path+"*.png"):
  before_path = f_name
  print(before_path)
  new_path = shutil.move(before_path, test_path+"/0/")
